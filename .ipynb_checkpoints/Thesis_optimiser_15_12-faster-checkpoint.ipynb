# %%
# Reload and core imports
# %reload_ext autoreload
# %autoreload 2

# All-in-one imports
import numpy as np
from dolfin import *
from src.Optimiser import objective_function#, #spacing_constraint

from solver2 import objective_function, solve_tidal_flow_velocities_fast, update_turbine_field, setup_tidal_solver
from src.solver import (
    setup_swe_problem, setup_boundary_markers_and_bcs, solve_tidal_flow_velocities
)
from src.turbines import (
    place_turbines_random, compute_turbine_power, summarize_turbine_power, plot_turbine_layout
)
from src.plots import plot_velocity_field, compute_power_field_plot, compare_layouts
import matplotlib.pyplot as plt
from scipy.optimize import minimize, differential_evolution
#from dolfin_adjoint import *

# PETSc (quiet mode)
from petsc4py import PETSc
PETSc.Options()["ksp_monitor"] = None
PETSc.Options()["ksp_view"] = None


print("✅ Thesis SWE solver ready (v15-12)")
# Out:
# ✅ Thesis SWE solver ready (v15-12)

# %%
# --- Physical and turbine parameters ---
rho = 1025.0         # Water density [kg/m³]
g = 9.81             # Gravitational acceleration [m/s²]
depth = 50.0         # Water depth [m]

C_T = 0.6             # Turbine thrust coefficient [-]
C_D = 0.0025          # Drag coefficient [-]
sigma = 5.0          # Wake Gaussian spread [m]
D = 5               # Turbine diameter
A_T = np.pi*D**2            # Turbine swept area [m²]

# --- Flow properties ---
U_inflow = 2.0       # Inflow velocity [m/s]
nu_eff = Constant(1.0)  # Effective viscosity [m²/s]
cb = 0.0025    # Bed friction coefficient [-]
viscosity = 1.0 #for now keep turbulent visc or eddy visc

#H = depth  # total depth (assuming flat bottom for now)
nu = viscosity  # viscosity coefficient

# --- Initial conditions ---
initial_condition_u = Constant((0.0, 0.0))
initial_condition_eta = Constant(0.0) # Start with no surface elevation

#----Mesh parameters----
Lx, Ly = 500.0, 400.0
Nx, Ny = 50, 40

n_turbines = 5             # number of turbines
min_spacing = 5*D     # minimum spacing between turbines [m]
#random.seed(42)             # set a fixed seed for reproducibility

#----Showing plots or not----
mesh_plot = True
turbine_position_plot = True


print(f"Initialized base parameters successfully.")
# Out:
# Initialized base parameters successfully.

# %%
#setting up mesh and initial turbine positions and boundary conditions and markers
mesh, W, w, u, eta, v, q, inflow, outflow, walls = setup_swe_problem(
    Lx, Ly, Nx, Ny, U_inflow, mesh_plot
)

turbine_positions = place_turbines_random(Lx, Ly, n_turbines, sigma, min_spacing)
x0 = np.array(turbine_positions).flatten() # Flatten initial turbine positions

plot_turbine_layout(mesh, turbine_positions, Lx, Ly, sigma, turbine_position_plot)
boundary_markers, bcs = setup_boundary_markers_and_bcs(mesh, W, Lx, U_inflow)

init_total_power, init_velocity = solve_tidal_flow_velocities(
    turbine_positions,
    w,
    W,
    mesh,
    bcs,
    rho,
    depth,
    nu,
    cb,
    g,
    C_T,
    A_T,
    sigma,
)
# Out:
# Success! Initialized u_init with U_inflow = 2.0 m/s on a 50x40 mesh.
# ✅ Successfully placed 5 turbines after 5 attempts.
# Initialized 5 turbines successfully.
# ✅ Boundary markers created and BCs applied:
#    - Inlet (ID=1): 2.0 m/s
#    - Outflow (ID=2): marked for future use
#     No Jacobian form specified for nonlinear variational problem.
#     Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#   WARNING: The number of integration points for each cell will be: 121
#            Consider using the option 'quadrature_degree' to reduce the number of points
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.401e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 3.109e-02 (tol = 1.000e-08) r (rel) = 2.219e-02 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.571e-05 (tol = 1.000e-08) r (rel) = 1.121e-05 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 7.670e-12 (tol = 1.000e-08) r (rel) = 5.475e-12 (tol = 1.000e-07)
#       Newton solver finished in 3 iterations and 3 linear solver iterations.
# The total power is 890.0 kW

# %%
# Optional: define custom initial population near your current design

solver_ctx = setup_tidal_solver(mesh, W, depth, nu, cb, g)
print("Solver context built.")
bounds = [(0, Lx), (0, Ly)] * n_turbines


def objective_wrapper(x):
    """Wrapper for optimisation using cached solver."""
    return objective_function(x, solver_ctx, mesh, bcs, rho, C_T, A_T, sigma, D)
       

init_population = np.vstack([
    x0,
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines),
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines),
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines),
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines)
])

# Run optimisation with fewer iterations for testing
result = differential_evolution(
    func=objective_wrapper,
    bounds=bounds,
    init=init_population,
    maxiter=10,        # limit iterations for speed
    popsize=15,
    mutation=(0.5, 1.9),
    workers=1,        # keep serial for FEniCS
    updating='immediate',
    disp=True,
    polish=False
)

# Extract the optimised positions
opt_positions = result.x.reshape(-1, 2)
print("Optimisation complete.\nOptimal layout:\n", opt_positions)
# Out:
# Solver context built.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Initial guess reset to inflow velocity field.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 2.672e+03 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 8.018e+02 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 2.406e+02 (tol = 1.000e-08) r (rel) = 9.002e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 7.217e+01 (tol = 1.000e-08) r (rel) = 2.701e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 2.165e+01 (tol = 1.000e-08) r (rel) = 8.102e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 6.495e+00 (tol = 1.000e-08) r (rel) = 2.431e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.949e+00 (tol = 1.000e-08) r (rel) = 7.292e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 5.846e-01 (tol = 1.000e-08) r (rel) = 2.188e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 1.754e-01 (tol = 1.000e-08) r (rel) = 6.563e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 5.261e-02 (tol = 1.000e-08) r (rel) = 1.969e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 1.578e-02 (tol = 1.000e-08) r (rel) = 5.906e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 4.735e-03 (tol = 1.000e-08) r (rel) = 1.772e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 1.421e-03 (tol = 1.000e-08) r (rel) = 5.316e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 4.262e-04 (tol = 1.000e-08) r (rel) = 1.595e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 1.278e-04 (tol = 1.000e-08) r (rel) = 4.784e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 894.6 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.314e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 3.938e-01 (tol = 1.000e-08) r (rel) = 2.997e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.181e-01 (tol = 1.000e-08) r (rel) = 8.991e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 3.543e-02 (tol = 1.000e-08) r (rel) = 2.697e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.063e-02 (tol = 1.000e-08) r (rel) = 8.091e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.189e-03 (tol = 1.000e-08) r (rel) = 2.427e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 9.567e-04 (tol = 1.000e-08) r (rel) = 7.282e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 2.870e-04 (tol = 1.000e-08) r (rel) = 2.185e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 8.611e-05 (tol = 1.000e-08) r (rel) = 6.554e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.583e-05 (tol = 1.000e-08) r (rel) = 1.966e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 7.749e-06 (tol = 1.000e-08) r (rel) = 5.899e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.325e-06 (tol = 1.000e-08) r (rel) = 1.770e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 6.975e-07 (tol = 1.000e-08) r (rel) = 5.309e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.092e-07 (tol = 1.000e-08) r (rel) = 1.593e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 6.277e-08 (tol = 1.000e-08) r (rel) = 4.778e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 901.1 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.418e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.255e-01 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.277e-01 (tol = 1.000e-08) r (rel) = 9.001e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 3.830e-02 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.149e-02 (tol = 1.000e-08) r (rel) = 8.101e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.447e-03 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.034e-03 (tol = 1.000e-08) r (rel) = 7.291e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.102e-04 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 9.307e-05 (tol = 1.000e-08) r (rel) = 6.562e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.792e-05 (tol = 1.000e-08) r (rel) = 1.969e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 8.376e-06 (tol = 1.000e-08) r (rel) = 5.906e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.513e-06 (tol = 1.000e-08) r (rel) = 1.772e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 7.539e-07 (tol = 1.000e-08) r (rel) = 5.315e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.262e-07 (tol = 1.000e-08) r (rel) = 1.595e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 6.785e-08 (tol = 1.000e-08) r (rel) = 4.784e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 897.0 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.432e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.300e-01 (tol = 1.000e-08) r (rel) = 3.004e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.291e-01 (tol = 1.000e-08) r (rel) = 9.016e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 3.873e-02 (tol = 1.000e-08) r (rel) = 2.705e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.162e-02 (tol = 1.000e-08) r (rel) = 8.117e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.486e-03 (tol = 1.000e-08) r (rel) = 2.435e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.046e-03 (tol = 1.000e-08) r (rel) = 7.305e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.137e-04 (tol = 1.000e-08) r (rel) = 2.192e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 9.412e-05 (tol = 1.000e-08) r (rel) = 6.575e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.824e-05 (tol = 1.000e-08) r (rel) = 1.972e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 8.471e-06 (tol = 1.000e-08) r (rel) = 5.917e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.541e-06 (tol = 1.000e-08) r (rel) = 1.775e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 7.624e-07 (tol = 1.000e-08) r (rel) = 5.326e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.287e-07 (tol = 1.000e-08) r (rel) = 1.598e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 6.861e-08 (tol = 1.000e-08) r (rel) = 4.793e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 892.6 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.463e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.393e-01 (tol = 1.000e-08) r (rel) = 3.004e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.319e-01 (tol = 1.000e-08) r (rel) = 9.016e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 3.957e-02 (tol = 1.000e-08) r (rel) = 2.705e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.187e-02 (tol = 1.000e-08) r (rel) = 8.116e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.561e-03 (tol = 1.000e-08) r (rel) = 2.435e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.068e-03 (tol = 1.000e-08) r (rel) = 7.305e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.205e-04 (tol = 1.000e-08) r (rel) = 2.191e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 9.615e-05 (tol = 1.000e-08) r (rel) = 6.574e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.885e-05 (tol = 1.000e-08) r (rel) = 1.972e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 8.654e-06 (tol = 1.000e-08) r (rel) = 5.917e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.596e-06 (tol = 1.000e-08) r (rel) = 1.775e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 7.788e-07 (tol = 1.000e-08) r (rel) = 5.325e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.337e-07 (tol = 1.000e-08) r (rel) = 1.598e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 7.010e-08 (tol = 1.000e-08) r (rel) = 4.793e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 895.9 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.619e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.862e-01 (tol = 1.000e-08) r (rel) = 3.003e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.459e-01 (tol = 1.000e-08) r (rel) = 9.015e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 4.379e-02 (tol = 1.000e-08) r (rel) = 2.705e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.314e-02 (tol = 1.000e-08) r (rel) = 8.116e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.942e-03 (tol = 1.000e-08) r (rel) = 2.435e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.183e-03 (tol = 1.000e-08) r (rel) = 7.304e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.548e-04 (tol = 1.000e-08) r (rel) = 2.191e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 1.064e-04 (tol = 1.000e-08) r (rel) = 6.574e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 3.193e-05 (tol = 1.000e-08) r (rel) = 1.972e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 9.578e-06 (tol = 1.000e-08) r (rel) = 5.917e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.873e-06 (tol = 1.000e-08) r (rel) = 1.775e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 8.620e-07 (tol = 1.000e-08) r (rel) = 5.325e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.586e-07 (tol = 1.000e-08) r (rel) = 1.597e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 7.758e-08 (tol = 1.000e-08) r (rel) = 4.792e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 892.3 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.568e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.707e-01 (tol = 1.000e-08) r (rel) = 3.003e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.413e-01 (tol = 1.000e-08) r (rel) = 9.012e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 4.239e-02 (tol = 1.000e-08) r (rel) = 2.704e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.272e-02 (tol = 1.000e-08) r (rel) = 8.113e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.815e-03 (tol = 1.000e-08) r (rel) = 2.434e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.145e-03 (tol = 1.000e-08) r (rel) = 7.302e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.434e-04 (tol = 1.000e-08) r (rel) = 2.190e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 1.030e-04 (tol = 1.000e-08) r (rel) = 6.571e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 3.090e-05 (tol = 1.000e-08) r (rel) = 1.971e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 9.271e-06 (tol = 1.000e-08) r (rel) = 5.914e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.781e-06 (tol = 1.000e-08) r (rel) = 1.774e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 8.344e-07 (tol = 1.000e-08) r (rel) = 5.323e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.503e-07 (tol = 1.000e-08) r (rel) = 1.597e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 7.509e-08 (tol = 1.000e-08) r (rel) = 4.791e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 900.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.511e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.528e-01 (tol = 1.000e-08) r (rel) = 2.996e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.358e-01 (tol = 1.000e-08) r (rel) = 8.987e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 4.074e-02 (tol = 1.000e-08) r (rel) = 2.696e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.222e-02 (tol = 1.000e-08) r (rel) = 8.088e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.666e-03 (tol = 1.000e-08) r (rel) = 2.426e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.100e-03 (tol = 1.000e-08) r (rel) = 7.279e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.300e-04 (tol = 1.000e-08) r (rel) = 2.184e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 9.899e-05 (tol = 1.000e-08) r (rel) = 6.551e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.970e-05 (tol = 1.000e-08) r (rel) = 1.965e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 8.909e-06 (tol = 1.000e-08) r (rel) = 5.896e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.673e-06 (tol = 1.000e-08) r (rel) = 1.769e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 8.018e-07 (tol = 1.000e-08) r (rel) = 5.307e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.405e-07 (tol = 1.000e-08) r (rel) = 1.592e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 7.216e-08 (tol = 1.000e-08) r (rel) = 4.776e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 895.8 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.494e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.482e-01 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.345e-01 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 4.035e-02 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.210e-02 (tol = 1.000e-08) r (rel) = 8.101e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.631e-03 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.089e-03 (tol = 1.000e-08) r (rel) = 7.291e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.268e-04 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 9.805e-05 (tol = 1.000e-08) r (rel) = 6.562e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.942e-05 (tol = 1.000e-08) r (rel) = 1.969e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 8.825e-06 (tol = 1.000e-08) r (rel) = 5.906e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.647e-06 (tol = 1.000e-08) r (rel) = 1.772e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 7.942e-07 (tol = 1.000e-08) r (rel) = 5.315e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.383e-07 (tol = 1.000e-08) r (rel) = 1.595e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 7.148e-08 (tol = 1.000e-08) r (rel) = 4.784e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 895.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.422e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 4.271e-01 (tol = 1.000e-08) r (rel) = 3.003e-01 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.282e-01 (tol = 1.000e-08) r (rel) = 9.015e-02 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 3.847e-02 (tol = 1.000e-08) r (rel) = 2.705e-02 (tol = 1.000e-07)
#       Newton iteration 4: r (abs) = 1.154e-02 (tol = 1.000e-08) r (rel) = 8.115e-03 (tol = 1.000e-07)
#       Newton iteration 5: r (abs) = 3.462e-03 (tol = 1.000e-08) r (rel) = 2.435e-03 (tol = 1.000e-07)
#       Newton iteration 6: r (abs) = 1.039e-03 (tol = 1.000e-08) r (rel) = 7.304e-04 (tol = 1.000e-07)
#       Newton iteration 7: r (abs) = 3.116e-04 (tol = 1.000e-08) r (rel) = 2.191e-04 (tol = 1.000e-07)
#       Newton iteration 8: r (abs) = 9.348e-05 (tol = 1.000e-08) r (rel) = 6.574e-05 (tol = 1.000e-07)
#       Newton iteration 9: r (abs) = 2.805e-05 (tol = 1.000e-08) r (rel) = 1.972e-05 (tol = 1.000e-07)
#       Newton iteration 10: r (abs) = 8.414e-06 (tol = 1.000e-08) r (rel) = 5.916e-06 (tol = 1.000e-07)
#       Newton iteration 11: r (abs) = 2.524e-06 (tol = 1.000e-08) r (rel) = 1.775e-06 (tol = 1.000e-07)
#       Newton iteration 12: r (abs) = 7.572e-07 (tol = 1.000e-08) r (rel) = 5.325e-07 (tol = 1.000e-07)
#       Newton iteration 13: r (abs) = 2.272e-07 (tol = 1.000e-08) r (rel) = 1.597e-07 (tol = 1.000e-07)
#       Newton iteration 14: r (abs) = 6.815e-08 (tol = 1.000e-08) r (rel) = 4.792e-08 (tol = 1.000e-07)
#       Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 900.5 kW
# differential_evolution step 1: f(x)= -901133.3400002031
# Optimisation complete.
# Optimal layout:
#  [[175.10932428 263.20824683]
#  [421.63395449 335.0360521 ]
#  [136.41643848 126.51723549]
#  [405.52668409  57.4189839 ]
#  [295.13668325 200.93989715]]

# %%
# --- Compute power and velocity for optimal layout ---
opt_total_power, opt_velocity = solve_tidal_flow_velocities(
    opt_positions,
    w, W, mesh, bcs,
    rho, depth, nu, cb, g,
    C_T, A_T, sigma,
)

# --- Compute per-turbine data for optimal layout ---
opt_turbine_powers, opt_turbine_velocities = compute_turbine_power(
    opt_velocity, opt_positions, rho, C_T, A_T
)

# --- Summarise results ---
opt_total_power_check, opt_max_park_power, _, _ = summarize_turbine_power(
    opt_turbine_powers, opt_turbine_velocities,
    rho, C_T, A_T, U_inflow, n_turbines
)

# --- Compute relative improvement and efficiency ---
improvement_pct = (opt_total_power_check - init_total_power) / init_total_power * 100
efficiency_pct = opt_total_power_check / opt_max_park_power * 100

# --- Print clean summary ---
print("\n========  LAYOUT OPTIMISATION SUMMARY  ========")
print(f"{'Initial total power:':35s} {init_total_power/1e3:10.2f} kW")
print(f"{'Optimised total power:':35s} {opt_total_power_check/1e3:10.2f} kW")
print(f"{'Maximum theoretical power (no wake):':35s} {opt_max_park_power/1e6:10.2f} MW")
print(f"{'Relative improvement:':35s} {improvement_pct:10.2f} %")
print(f"{'Farm efficiency:':35s} {efficiency_pct:10.2f} %")
print("===============================================\n")

# --- Combined layout comparison ---
compare_layouts(mesh, Lx, Ly, turbine_positions, opt_positions, sigma)

# --- Velocity and power field plots for optimal layout ---
plot_velocity_field(w, opt_positions, sigma)
compute_power_field_plot(C_T, rho, A_T, w, opt_positions, sigma)
# Out:
#     No Jacobian form specified for nonlinear variational problem.
#     Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#   WARNING: The number of integration points for each cell will be: 121
#            Consider using the option 'quadrature_degree' to reduce the number of points
#     Solving nonlinear variational problem.
#       Newton iteration 0: r (abs) = 1.462e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#       Newton iteration 1: r (abs) = 1.376e-02 (tol = 1.000e-08) r (rel) = 9.412e-03 (tol = 1.000e-07)
#       Newton iteration 2: r (abs) = 1.417e-06 (tol = 1.000e-08) r (rel) = 9.694e-07 (tol = 1.000e-07)
#       Newton iteration 3: r (abs) = 1.585e-12 (tol = 1.000e-08) r (rel) = 1.084e-12 (tol = 1.000e-07)
#       Newton solver finished in 3 iterations and 3 linear solver iterations.
# The total power is 894.0 kW
# Maximum theoretical power per turbine (Betz-adjusted): 135.25 kW
# Momentum-sink (raw thrust) power per turbine:          193.21 kW
# Max total power: 0.97 MW
#
# Turbine performance summary:
# -------------------------------------------------------
# Turbine  1: Velocity = 1.96 m/s | Power = 181.41 kW
# Turbine  2: Velocity = 1.93 m/s | Power = 174.06 kW
# Turbine  3: Velocity = 1.96 m/s | Power = 182.74 kW
# Turbine  4: Velocity = 1.94 m/s | Power = 175.89 kW
# Turbine  5: Velocity = 1.95 m/s | Power = 179.91 kW
# -------------------------------------------------------
# Total extracted power: 0.89 MW
# Fraction of park capacity: 92.54%
#
#
# ========  LAYOUT OPTIMISATION SUMMARY  ========
# Initial total power:                    890.01 kW
# Optimised total power:                  894.02 kW
# Maximum theoretical power (no wake):       0.97 MW
# Relative improvement:                     0.45 %
# Farm efficiency:                         92.54 %
# ===============================================
