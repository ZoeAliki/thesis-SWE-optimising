# %%
# Reload and core imports
# %reload_ext autoreload
# %autoreload 2

# All-in-one imports
import numpy as np
from dolfin import *
from dolfin_adjoint import *
#from src.Optimiser import objective_function#, #spacing_constraint

from solver2 import objective_function, solve_tidal_flow_velocities_fast, update_turbine_field, setup_tidal_solver
from src.solver import (
    setup_swe_problem, setup_boundary_markers_and_bcs, solve_tidal_flow_velocities
)
from src.turbines import (
    place_turbines_random, compute_turbine_power, summarize_turbine_power, plot_turbine_layout
)
from src.plots import plot_velocity_field, compute_power_field_plot, compare_layouts
import matplotlib.pyplot as plt
from scipy.optimize import minimize, differential_evolution
#from dolfin_adjoint import *

# PETSc (quiet mode)
from petsc4py import PETSc
PETSc.Options()["ksp_monitor"] = None
PETSc.Options()["ksp_view"] = None


print("✅ Thesis SWE solver ready (v16-12)")
# Out:
# ✅ Thesis SWE solver ready (v16-12)

# %%
# --- Physical and turbine parameters ---
rho = 1025.0         # Water density [kg/m³]
g = 9.81             # Gravitational acceleration [m/s²]
depth = 50.0         # Water depth [m]

C_T = 0.6             # Turbine thrust coefficient [-]
C_D = 0.0025          # Drag coefficient [-]
sigma = 5.0          # Wake Gaussian spread [m]
D = 5               # Turbine diameter
A_T = np.pi*D**2            # Turbine swept area [m²]

# --- Flow properties ---
U_inflow = 2.0       # Inflow velocity [m/s]
nu_eff = Constant(1.0)  # Effective viscosity [m²/s]
cb = 0.0025    # Bed friction coefficient [-]
viscosity = 1.0 #for now keep turbulent visc or eddy visc

#H = depth  # total depth (assuming flat bottom for now)
nu = viscosity  # viscosity coefficient

# --- Initial conditions ---
initial_condition_u = Constant((0.0, 0.0))
initial_condition_eta = Constant(0.0) # Start with no surface elevation

#----Mesh parameters----
Lx, Ly = 500.0, 400.0
Nx, Ny = 50, 40

n_turbines = 2            # number of turbines
min_spacing = 5*D     # minimum spacing between turbines [m]
#random.seed(42)             # set a fixed seed for reproducibility

#----Showing plots or not----
mesh_plot = True
turbine_position_plot = True


print(f"Initialized base parameters successfully.")
# Out:
# Initialized base parameters successfully.

# %%
#setting up mesh and initial turbine positions and boundary conditions and markers
mesh, W, w, u, eta, v, q, inflow, outflow, walls = setup_swe_problem(
    Lx, Ly, Nx, Ny, U_inflow, mesh_plot
)

turbine_positions = place_turbines_random(Lx, Ly, n_turbines, sigma, min_spacing)
x0 = np.array(turbine_positions).flatten() # Flatten initial turbine positions

plot_turbine_layout(mesh, turbine_positions, Lx, Ly, sigma, turbine_position_plot)
boundary_markers, bcs = setup_boundary_markers_and_bcs(mesh, W, Lx, U_inflow)

init_total_power, init_velocity = solve_tidal_flow_velocities(
    turbine_positions,
    w,
    W,
    mesh,
    bcs,
    rho,
    depth,
    nu,
    cb,
    g,
    C_T,
    A_T,
    sigma,
)
# Out:
# Success! Initialized u_init with U_inflow = 2.0 m/s on a 50x40 mesh.
# ✅ Successfully placed 2 turbines after 2 attempts.
# Initialized 2 turbines successfully.
# ✅ Boundary markers created and BCs applied:
#    - Inlet (ID=1): 2.0 m/s
#    - Outflow (ID=2): marked for future use
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#   WARNING: The number of integration points for each cell will be: 121
#            Consider using the option 'quadrature_degree' to reduce the number of points
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.781e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.853e-02 (tol = 1.000e-08) r (rel) = 1.895e-02 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.822e-06 (tol = 1.000e-08) r (rel) = 7.997e-06 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.435e-12 (tol = 1.000e-08) r (rel) = 2.490e-12 (tol = 1.000e-07)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# The total power is 354.5 kW

# %%
#  SETUP


solver_ctx = setup_tidal_solver(mesh, W, depth, nu, cb, g)
print("Solver context built, Zoë.")

bounds = [(0, Lx), (0, Ly)] * n_turbines

# Prepare unified objective wrapper
def objective_wrapper(x):
    return objective_function(x, solver_ctx, mesh, bcs, rho, C_T, A_T, sigma, D)

# Optional: small randomised initial population (diversify search)
init_population = np.vstack([
    x0,
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines),
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines),
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines),
    x0 + np.random.uniform(-0.05, 0.05, size=len(x0)) * np.array([Lx, Ly] * n_turbines)
])

# ------------------------------------------------------------
#  GLOBAL OPTIMISATION (Differential Evolution)
# ------------------------------------------------------------
print("\n 👍 Starting global differential evolution search.")

global_result = differential_evolution(
    func=objective_wrapper,     # call wrapper (no explicit args)
    bounds=bounds,
    init=init_population,       # start near current layout
    maxiter=3,                 # broad exploration
    popsize=5,
    mutation=(0.7, 1.2),
    recombination=0.8,
    updating='immediate',
    workers=1,                  # FEniCS and multiprocessing don't mix
    disp=False,
    polish=False                # we'll polish ourselves
)

print(f"\n Global search complete.")
print(f"   Best preliminary objective (negative power): {global_result.fun:.3e}")

# ------------------------------------------------------------
#  LOCAL OPTIMISATION (L‑BFGS‑B refinement)
# ------------------------------------------------------------
print("\n⚙️ Refining solution locally with L‑BFGS‑B ...")

res_local = minimize(
    objective_wrapper,
    x0=global_result.x,         # start from DE best layout
    method='L-BFGS-B',
    bounds=bounds,
    options={'maxiter': 5, 'disp': True}
)

# ------------------------------------------------------------
#  CHOOSE FINAL RESULT
# ------------------------------------------------------------
if res_local.fun < global_result.fun:
    best_result = res_local
    source = "Local (refined)"
else:
    best_result = global_result
    source = "Global (no improvement)"

opt_positions = best_result.x.reshape(-1, 2)
print(f"\n 👌 Hybrid optimisation complete — using {source} result.")
print(f" 😊  Final objective (negative power): {best_result.fun:.3e}")

best_power_global = -global_result.fun
best_power_local = -res_local.fun
print(f"Best power after global search: {best_power_global/1e3:.2f} kW")
print(f"Best power after local refinement: {best_power_local/1e3:.2f} kW")
# Out:
# Solver context built, Zoë.
#
#  👍 Starting global differential evolution search.
# Initial guess reset to inflow velocity field.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.672e+03 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 8.018e+02 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 2.406e+02 (tol = 1.000e-08) r (rel) = 9.002e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 7.217e+01 (tol = 1.000e-08) r (rel) = 2.701e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 2.165e+01 (tol = 1.000e-08) r (rel) = 8.102e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 6.495e+00 (tol = 1.000e-08) r (rel) = 2.431e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 1.949e+00 (tol = 1.000e-08) r (rel) = 7.292e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 5.846e-01 (tol = 1.000e-08) r (rel) = 2.188e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 1.754e-01 (tol = 1.000e-08) r (rel) = 6.563e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 5.261e-02 (tol = 1.000e-08) r (rel) = 1.969e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 1.578e-02 (tol = 1.000e-08) r (rel) = 5.906e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 4.735e-03 (tol = 1.000e-08) r (rel) = 1.772e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 1.421e-03 (tol = 1.000e-08) r (rel) = 5.316e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 4.262e-04 (tol = 1.000e-08) r (rel) = 1.595e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 1.278e-04 (tol = 1.000e-08) r (rel) = 4.784e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 357.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.936e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.683e-01 (tol = 1.000e-08) r (rel) = 3.003e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 8.053e-02 (tol = 1.000e-08) r (rel) = 9.013e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.416e-02 (tol = 1.000e-08) r (rel) = 2.704e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 7.249e-03 (tol = 1.000e-08) r (rel) = 8.113e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.175e-03 (tol = 1.000e-08) r (rel) = 2.434e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 6.525e-04 (tol = 1.000e-08) r (rel) = 7.302e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.957e-04 (tol = 1.000e-08) r (rel) = 2.191e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.872e-05 (tol = 1.000e-08) r (rel) = 6.572e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.762e-05 (tol = 1.000e-08) r (rel) = 1.972e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.285e-06 (tol = 1.000e-08) r (rel) = 5.915e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.585e-06 (tol = 1.000e-08) r (rel) = 1.774e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.756e-07 (tol = 1.000e-08) r (rel) = 5.323e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.427e-07 (tol = 1.000e-08) r (rel) = 1.597e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.281e-08 (tol = 1.000e-08) r (rel) = 4.791e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 355.6 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.491e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.234e-01 (tol = 1.000e-08) r (rel) = 2.982e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 6.689e-02 (tol = 1.000e-08) r (rel) = 8.929e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.006e-02 (tol = 1.000e-08) r (rel) = 2.677e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.016e-03 (tol = 1.000e-08) r (rel) = 8.031e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.805e-03 (tol = 1.000e-08) r (rel) = 2.409e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 5.414e-04 (tol = 1.000e-08) r (rel) = 7.227e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.624e-04 (tol = 1.000e-08) r (rel) = 2.168e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 4.873e-05 (tol = 1.000e-08) r (rel) = 6.504e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.462e-05 (tol = 1.000e-08) r (rel) = 1.951e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 4.385e-06 (tol = 1.000e-08) r (rel) = 5.854e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.316e-06 (tol = 1.000e-08) r (rel) = 1.756e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 3.947e-07 (tol = 1.000e-08) r (rel) = 5.268e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.184e-07 (tol = 1.000e-08) r (rel) = 1.581e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.552e-08 (tol = 1.000e-08) r (rel) = 4.742e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 354.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.121e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.443e-01 (tol = 1.000e-08) r (rel) = 3.008e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.335e-02 (tol = 1.000e-08) r (rel) = 9.032e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.201e-02 (tol = 1.000e-08) r (rel) = 2.710e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.604e-03 (tol = 1.000e-08) r (rel) = 8.132e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.981e-03 (tol = 1.000e-08) r (rel) = 2.440e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 5.944e-04 (tol = 1.000e-08) r (rel) = 7.319e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.783e-04 (tol = 1.000e-08) r (rel) = 2.196e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.349e-05 (tol = 1.000e-08) r (rel) = 6.587e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.605e-05 (tol = 1.000e-08) r (rel) = 1.976e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 4.814e-06 (tol = 1.000e-08) r (rel) = 5.929e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.444e-06 (tol = 1.000e-08) r (rel) = 1.779e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.333e-07 (tol = 1.000e-08) r (rel) = 5.336e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.300e-07 (tol = 1.000e-08) r (rel) = 1.601e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.900e-08 (tol = 1.000e-08) r (rel) = 4.802e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 357.8 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.091e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.128e-01 (tol = 1.000e-08) r (rel) = 3.001e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 6.387e-02 (tol = 1.000e-08) r (rel) = 9.008e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 1.916e-02 (tol = 1.000e-08) r (rel) = 2.703e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 5.750e-03 (tol = 1.000e-08) r (rel) = 8.108e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.725e-03 (tol = 1.000e-08) r (rel) = 2.433e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 5.175e-04 (tol = 1.000e-08) r (rel) = 7.298e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.552e-04 (tol = 1.000e-08) r (rel) = 2.189e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 4.657e-05 (tol = 1.000e-08) r (rel) = 6.568e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.397e-05 (tol = 1.000e-08) r (rel) = 1.970e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 4.192e-06 (tol = 1.000e-08) r (rel) = 5.911e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.257e-06 (tol = 1.000e-08) r (rel) = 1.773e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 3.772e-07 (tol = 1.000e-08) r (rel) = 5.320e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.132e-07 (tol = 1.000e-08) r (rel) = 1.596e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.395e-08 (tol = 1.000e-08) r (rel) = 4.788e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.900e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.773e-01 (tol = 1.000e-08) r (rel) = 3.006e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 5.323e-02 (tol = 1.000e-08) r (rel) = 9.022e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 1.597e-02 (tol = 1.000e-08) r (rel) = 2.707e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 4.792e-03 (tol = 1.000e-08) r (rel) = 8.122e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.438e-03 (tol = 1.000e-08) r (rel) = 2.437e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 4.313e-04 (tol = 1.000e-08) r (rel) = 7.310e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.294e-04 (tol = 1.000e-08) r (rel) = 2.193e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 3.881e-05 (tol = 1.000e-08) r (rel) = 6.579e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.164e-05 (tol = 1.000e-08) r (rel) = 1.974e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 3.493e-06 (tol = 1.000e-08) r (rel) = 5.921e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.048e-06 (tol = 1.000e-08) r (rel) = 1.776e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 3.144e-07 (tol = 1.000e-08) r (rel) = 5.329e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 9.432e-08 (tol = 1.000e-08) r (rel) = 1.599e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 2.830e-08 (tol = 1.000e-08) r (rel) = 4.796e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 357.0 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.688e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.595e-01 (tol = 1.000e-08) r (rel) = 2.987e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.777e-02 (tol = 1.000e-08) r (rel) = 8.951e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.332e-02 (tol = 1.000e-08) r (rel) = 2.685e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.996e-03 (tol = 1.000e-08) r (rel) = 8.053e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.099e-03 (tol = 1.000e-08) r (rel) = 2.416e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 6.296e-04 (tol = 1.000e-08) r (rel) = 7.247e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.889e-04 (tol = 1.000e-08) r (rel) = 2.174e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.667e-05 (tol = 1.000e-08) r (rel) = 6.523e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.700e-05 (tol = 1.000e-08) r (rel) = 1.957e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.100e-06 (tol = 1.000e-08) r (rel) = 5.870e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.530e-06 (tol = 1.000e-08) r (rel) = 1.761e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.590e-07 (tol = 1.000e-08) r (rel) = 5.283e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.377e-07 (tol = 1.000e-08) r (rel) = 1.585e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.131e-08 (tol = 1.000e-08) r (rel) = 4.755e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 357.6 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 6.632e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.990e-01 (tol = 1.000e-08) r (rel) = 3.001e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 5.974e-02 (tol = 1.000e-08) r (rel) = 9.008e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 1.792e-02 (tol = 1.000e-08) r (rel) = 2.703e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 5.377e-03 (tol = 1.000e-08) r (rel) = 8.108e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.613e-03 (tol = 1.000e-08) r (rel) = 2.433e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 4.839e-04 (tol = 1.000e-08) r (rel) = 7.298e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.452e-04 (tol = 1.000e-08) r (rel) = 2.189e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 4.356e-05 (tol = 1.000e-08) r (rel) = 6.568e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.307e-05 (tol = 1.000e-08) r (rel) = 1.970e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 3.920e-06 (tol = 1.000e-08) r (rel) = 5.911e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.176e-06 (tol = 1.000e-08) r (rel) = 1.773e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 3.528e-07 (tol = 1.000e-08) r (rel) = 5.320e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.058e-07 (tol = 1.000e-08) r (rel) = 1.596e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.175e-08 (tol = 1.000e-08) r (rel) = 4.788e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 356.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.010e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 3.028e-01 (tol = 1.000e-08) r (rel) = 2.999e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 9.086e-02 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.726e-02 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 8.178e-03 (tol = 1.000e-08) r (rel) = 8.101e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.454e-03 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 7.361e-04 (tol = 1.000e-08) r (rel) = 7.291e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 2.208e-04 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 6.625e-05 (tol = 1.000e-08) r (rel) = 6.562e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.987e-05 (tol = 1.000e-08) r (rel) = 1.969e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.962e-06 (tol = 1.000e-08) r (rel) = 5.906e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.789e-06 (tol = 1.000e-08) r (rel) = 1.772e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 5.366e-07 (tol = 1.000e-08) r (rel) = 5.315e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.610e-07 (tol = 1.000e-08) r (rel) = 1.595e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.829e-08 (tol = 1.000e-08) r (rel) = 4.784e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 354.6 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.819e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.339e-01 (tol = 1.000e-08) r (rel) = 2.991e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.011e-02 (tol = 1.000e-08) r (rel) = 8.966e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.103e-02 (tol = 1.000e-08) r (rel) = 2.689e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.308e-03 (tol = 1.000e-08) r (rel) = 8.067e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.892e-03 (tol = 1.000e-08) r (rel) = 2.420e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 5.677e-04 (tol = 1.000e-08) r (rel) = 7.260e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.703e-04 (tol = 1.000e-08) r (rel) = 2.178e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.109e-05 (tol = 1.000e-08) r (rel) = 6.534e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.533e-05 (tol = 1.000e-08) r (rel) = 1.960e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 4.598e-06 (tol = 1.000e-08) r (rel) = 5.881e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.379e-06 (tol = 1.000e-08) r (rel) = 1.764e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.138e-07 (tol = 1.000e-08) r (rel) = 5.293e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.242e-07 (tol = 1.000e-08) r (rel) = 1.588e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.725e-08 (tol = 1.000e-08) r (rel) = 4.763e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 356.4 kW
#
#  Global search complete.
#    Best preliminary objective (negative power): -3.585e+05
#
# ⚙️ Refining solution locally with L‑BFGS‑B ...
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.148e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.746e-01 (tol = 1.000e-08) r (rel) = 3.002e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 8.243e-02 (tol = 1.000e-08) r (rel) = 9.010e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.473e-02 (tol = 1.000e-08) r (rel) = 2.704e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 7.420e-03 (tol = 1.000e-08) r (rel) = 8.111e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.226e-03 (tol = 1.000e-08) r (rel) = 2.433e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 6.678e-04 (tol = 1.000e-08) r (rel) = 7.300e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 2.003e-04 (tol = 1.000e-08) r (rel) = 2.190e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 6.010e-05 (tol = 1.000e-08) r (rel) = 6.570e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.803e-05 (tol = 1.000e-08) r (rel) = 1.971e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.409e-06 (tol = 1.000e-08) r (rel) = 5.913e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.623e-06 (tol = 1.000e-08) r (rel) = 1.774e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.868e-07 (tol = 1.000e-08) r (rel) = 5.322e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.460e-07 (tol = 1.000e-08) r (rel) = 1.597e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.381e-08 (tol = 1.000e-08) r (rel) = 4.790e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.383e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.315e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 3.945e-09 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.028e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.075e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.855e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.049e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.396e-01 (tol = 1.000e-08) r (rel) = 2.977e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.172e-02 (tol = 1.000e-08) r (rel) = 8.911e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.150e-02 (tol = 1.000e-08) r (rel) = 2.671e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.449e-03 (tol = 1.000e-08) r (rel) = 8.013e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.935e-03 (tol = 1.000e-08) r (rel) = 2.404e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 5.804e-04 (tol = 1.000e-08) r (rel) = 7.211e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.741e-04 (tol = 1.000e-08) r (rel) = 2.163e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.223e-05 (tol = 1.000e-08) r (rel) = 6.490e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.567e-05 (tol = 1.000e-08) r (rel) = 1.947e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 4.701e-06 (tol = 1.000e-08) r (rel) = 5.841e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.410e-06 (tol = 1.000e-08) r (rel) = 1.752e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.231e-07 (tol = 1.000e-08) r (rel) = 5.257e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.269e-07 (tol = 1.000e-08) r (rel) = 1.577e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.808e-08 (tol = 1.000e-08) r (rel) = 4.731e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 386.4 kW
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.822e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.147e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 3.440e-09 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# ✅ Power for current iteration: 386.4 kW
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.435e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 386.4 kW
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.440e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 386.4 kW
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.435e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 386.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.416e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.547e-01 (tol = 1.000e-08) r (rel) = 3.026e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.663e-02 (tol = 1.000e-08) r (rel) = 9.105e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.301e-02 (tol = 1.000e-08) r (rel) = 2.734e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.904e-03 (tol = 1.000e-08) r (rel) = 8.203e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.071e-03 (tol = 1.000e-08) r (rel) = 2.461e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 6.214e-04 (tol = 1.000e-08) r (rel) = 7.384e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.864e-04 (tol = 1.000e-08) r (rel) = 2.215e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.593e-05 (tol = 1.000e-08) r (rel) = 6.645e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.678e-05 (tol = 1.000e-08) r (rel) = 1.994e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.034e-06 (tol = 1.000e-08) r (rel) = 5.981e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.510e-06 (tol = 1.000e-08) r (rel) = 1.794e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.530e-07 (tol = 1.000e-08) r (rel) = 5.383e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.359e-07 (tol = 1.000e-08) r (rel) = 1.615e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.077e-08 (tol = 1.000e-08) r (rel) = 4.845e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 362.7 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.080e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.224e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 3.672e-09 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# ✅ Power for current iteration: 362.7 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
# ✅ Power for current iteration: 362.7 kW
#   Newton iteration 0: r (abs) = 3.744e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.755e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 362.7 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
# ✅ Power for current iteration: 362.7 kW
#   Newton iteration 0: r (abs) = 3.711e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.014e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 3.041e-01 (tol = 1.000e-08) r (rel) = 2.999e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 9.124e-02 (tol = 1.000e-08) r (rel) = 8.999e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.737e-02 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 8.212e-03 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.464e-03 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 7.391e-04 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 2.217e-04 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 6.652e-05 (tol = 1.000e-08) r (rel) = 6.561e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.996e-05 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.987e-06 (tol = 1.000e-08) r (rel) = 5.905e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.796e-06 (tol = 1.000e-08) r (rel) = 1.771e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 5.388e-07 (tol = 1.000e-08) r (rel) = 5.314e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.616e-07 (tol = 1.000e-08) r (rel) = 1.594e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.849e-08 (tol = 1.000e-08) r (rel) = 4.783e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 360.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.851e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.455e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 4.366e-09 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# ✅ Power for current iteration: 360.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.429e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 360.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.437e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 360.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.418e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 360.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.983e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.997e-01 (tol = 1.000e-08) r (rel) = 3.002e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 8.994e-02 (tol = 1.000e-08) r (rel) = 9.009e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.698e-02 (tol = 1.000e-08) r (rel) = 2.703e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 8.096e-03 (tol = 1.000e-08) r (rel) = 8.110e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.429e-03 (tol = 1.000e-08) r (rel) = 2.433e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 7.286e-04 (tol = 1.000e-08) r (rel) = 7.299e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 2.186e-04 (tol = 1.000e-08) r (rel) = 2.190e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 6.558e-05 (tol = 1.000e-08) r (rel) = 6.569e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.967e-05 (tol = 1.000e-08) r (rel) = 1.971e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 5.902e-06 (tol = 1.000e-08) r (rel) = 5.912e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.771e-06 (tol = 1.000e-08) r (rel) = 1.774e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 5.312e-07 (tol = 1.000e-08) r (rel) = 5.321e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.593e-07 (tol = 1.000e-08) r (rel) = 1.596e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 4.780e-08 (tol = 1.000e-08) r (rel) = 4.789e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 354.1 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.781e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.434e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 4.303e-09 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# ✅ Power for current iteration: 354.1 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.411e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 354.1 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.393e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 354.1 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.357e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 354.1 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.340e-01 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.002e-01 (tol = 1.000e-08) r (rel) = 2.999e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 3.005e-02 (tol = 1.000e-08) r (rel) = 8.997e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 9.016e-03 (tol = 1.000e-08) r (rel) = 2.699e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 2.705e-03 (tol = 1.000e-08) r (rel) = 8.098e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 8.114e-04 (tol = 1.000e-08) r (rel) = 2.429e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 2.434e-04 (tol = 1.000e-08) r (rel) = 7.288e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 7.303e-05 (tol = 1.000e-08) r (rel) = 2.186e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 2.191e-05 (tol = 1.000e-08) r (rel) = 6.559e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 6.572e-06 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 1.972e-06 (tol = 1.000e-08) r (rel) = 5.903e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 5.915e-07 (tol = 1.000e-08) r (rel) = 1.771e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 1.775e-07 (tol = 1.000e-08) r (rel) = 5.313e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 5.324e-08 (tol = 1.000e-08) r (rel) = 1.594e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 1.597e-08 (tol = 1.000e-08) r (rel) = 4.781e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 357.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.626e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 4.878e-09 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# ✅ Power for current iteration: 357.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.913e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 357.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.012e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 357.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.735e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 357.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 6.525e-02 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.957e-02 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 5.872e-03 (tol = 1.000e-08) r (rel) = 8.999e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 1.761e-03 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 5.284e-04 (tol = 1.000e-08) r (rel) = 8.099e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.585e-04 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 4.756e-05 (tol = 1.000e-08) r (rel) = 7.289e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.427e-05 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 4.280e-06 (tol = 1.000e-08) r (rel) = 6.560e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.284e-06 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 3.852e-07 (tol = 1.000e-08) r (rel) = 5.904e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.156e-07 (tol = 1.000e-08) r (rel) = 1.771e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 3.467e-08 (tol = 1.000e-08) r (rel) = 5.314e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 1.040e-08 (tol = 1.000e-08) r (rel) = 1.594e-07 (tol = 1.000e-07)
#   Newton iteration 14: r (abs) = 3.120e-09 (tol = 1.000e-08) r (rel) = 4.782e-08 (tol = 1.000e-07)
#   Newton solver finished in 14 iterations and 14 linear solver iterations.
# ✅ Power for current iteration: 358.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.437e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.445e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.578e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.269e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.2 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.455e-02 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 7.365e-03 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 2.209e-03 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 6.628e-04 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 1.988e-04 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 5.965e-05 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 1.790e-05 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 5.369e-06 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 1.611e-06 (tol = 1.000e-08) r (rel) = 6.561e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 4.832e-07 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 1.450e-07 (tol = 1.000e-08) r (rel) = 5.905e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 4.349e-08 (tol = 1.000e-08) r (rel) = 1.771e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 1.305e-08 (tol = 1.000e-08) r (rel) = 5.314e-07 (tol = 1.000e-07)
#   Newton iteration 13: r (abs) = 3.914e-09 (tol = 1.000e-08) r (rel) = 1.594e-07 (tol = 1.000e-07)
#   Newton solver finished in 13 iterations and 13 linear solver iterations.
# ✅ Power for current iteration: 358.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
# ✅ Power for current iteration: 358.4 kW
#   Newton iteration 0: r (abs) = 4.215e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.234e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.372e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.053e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.4 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.125e-03 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.437e-03 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.312e-04 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.194e-04 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 6.581e-05 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 1.974e-05 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 5.923e-06 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.777e-06 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.331e-07 (tol = 1.000e-08) r (rel) = 6.561e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.599e-07 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 4.798e-08 (tol = 1.000e-08) r (rel) = 5.905e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 1.439e-08 (tol = 1.000e-08) r (rel) = 1.771e-06 (tol = 1.000e-07)
#   Newton iteration 12: r (abs) = 4.318e-09 (tol = 1.000e-08) r (rel) = 5.314e-07 (tol = 1.000e-07)
#   Newton solver finished in 12 iterations and 12 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.614e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.637e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.775e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.453e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.686e-03 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 8.058e-04 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 2.417e-04 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 7.252e-05 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 2.176e-05 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 6.527e-06 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 1.958e-06 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 5.874e-07 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 1.762e-07 (tol = 1.000e-08) r (rel) = 6.561e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 5.287e-08 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
#   Newton iteration 10: r (abs) = 1.586e-08 (tol = 1.000e-08) r (rel) = 5.905e-06 (tol = 1.000e-07)
#   Newton iteration 11: r (abs) = 4.758e-09 (tol = 1.000e-08) r (rel) = 1.771e-06 (tol = 1.000e-07)
#   Newton solver finished in 11 iterations and 11 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.050e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.074e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.214e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.890e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.878e-04 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 2.663e-04 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 7.990e-05 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.397e-05 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 7.191e-06 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.157e-06 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 6.472e-07 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 1.942e-07 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton iteration 8: r (abs) = 5.825e-08 (tol = 1.000e-08) r (rel) = 6.561e-05 (tol = 1.000e-07)
#   Newton iteration 9: r (abs) = 1.747e-08 (tol = 1.000e-08) r (rel) = 1.968e-05 (tol = 1.000e-07)
# ...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.206e-05 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 9.617e-06 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 2.885e-06 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 8.655e-07 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 2.597e-07 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 7.790e-08 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 2.337e-08 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton iteration 7: r (abs) = 7.011e-09 (tol = 1.000e-08) r (rel) = 2.187e-04 (tol = 1.000e-07)
#   Newton solver finished in 7 iterations and 7 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.292e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.318e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.461e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.130e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.060e-05 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 3.180e-06 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 9.540e-07 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 2.862e-07 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 8.586e-08 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 2.576e-08 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton iteration 6: r (abs) = 7.727e-09 (tol = 1.000e-08) r (rel) = 7.290e-04 (tol = 1.000e-07)
#   Newton solver finished in 6 iterations and 6 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.007e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.032e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.176e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.844e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.509e-06 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.053e-06 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 3.158e-07 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 9.473e-08 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 2.842e-08 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton iteration 5: r (abs) = 8.526e-09 (tol = 1.000e-08) r (rel) = 2.430e-03 (tol = 1.000e-07)
#   Newton solver finished in 5 iterations and 5 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.804e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.829e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.974e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.641e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.166e-06 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 3.497e-07 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 1.049e-07 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 3.147e-08 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 9.441e-09 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton solver finished in 4 iterations and 4 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.717e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.743e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.888e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.554e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.918e-07 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.176e-07 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 3.527e-08 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 1.058e-08 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton iteration 4: r (abs) = 3.174e-09 (tol = 1.000e-08) r (rel) = 8.100e-03 (tol = 1.000e-07)
#   Newton solver finished in 4 iterations and 4 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.480e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.504e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.638e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.324e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.295e-07 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 3.886e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 1.166e-08 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 3.498e-09 (tol = 1.000e-08) r (rel) = 2.700e-02 (tol = 1.000e-07)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.800e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.824e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.960e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.642e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.526e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.358e-08 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 4.073e-09 (tol = 1.000e-08) r (rel) = 9.000e-02 (tol = 1.000e-07)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.370e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.395e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.532e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.211e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.787e-08 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 5.362e-09 (tol = 1.000e-08) r (rel) = 3.000e-01 (tol = 1.000e-07)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.650e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.675e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.816e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.489e-09 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# ✅ Power for current iteration: 358.5 kW
#
#  👌 Hybrid optimisation complete — using Global (no improvement) result.
#  😊  Final objective (negative power): -3.585e+05
# Best power after global search: 358.54 kW
# Best power after local refinement: 358.54 kW

# %%
# --- Compute power and velocity for optimal layout ---

opt_total_power, opt_velocity = solve_tidal_flow_velocities(
    opt_positions,
    w, W, mesh, bcs,
    rho, depth, nu, cb, g,
    C_T, A_T, sigma,
)

# --- Compute per-turbine data for optimal layout ---
opt_turbine_powers, opt_turbine_velocities = compute_turbine_power(
    opt_velocity, opt_positions, rho, C_T, A_T
)

# --- Summarise results ---
opt_total_power_check, opt_max_park_power, _, _ = summarize_turbine_power(
    opt_turbine_powers, opt_turbine_velocities,
    rho, C_T, A_T, U_inflow, n_turbines
)

# --- Compute relative improvement and efficiency ---
improvement_pct = (opt_total_power_check - init_total_power) / init_total_power * 100
efficiency_pct = opt_total_power_check / opt_max_park_power * 100

# --- Print clean summary ---
print("\n========  LAYOUT OPTIMISATION SUMMARY  ========")
print(f"{'Initial total power:':35s} {init_total_power/1e3:10.2f} kW")
print(f"{'Optimised total power:':35s} {opt_total_power_check/1e3:10.2f} kW")
print(f"{'Maximum theoretical power (no wake):':35s} {opt_max_park_power/1e6:10.2f} MW")
print(f"{'Relative improvement:':35s} {improvement_pct:10.2f} %")
print(f"{'Farm efficiency:':35s} {efficiency_pct:10.2f} %")
print("===============================================\n")

# --- Combined layout comparison ---
compare_layouts(mesh, Lx, Ly, turbine_positions, opt_positions, sigma)

# --- Velocity and power field plots for optimal layout ---
plot_velocity_field(w, opt_positions, sigma, Lx, Ly)
compute_power_field_plot(C_T, rho, A_T, w, opt_positions, sigma, Lx, Ly)
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#   WARNING: The number of integration points for each cell will be: 121
#            Consider using the option 'quadrature_degree' to reduce the number of points
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.022e+00 (tol = 1.000e-08) r (rel) = 1.000e+00 (tol = 1.000e-07)
#   Newton iteration 1: r (abs) = 1.040e-02 (tol = 1.000e-08) r (rel) = 1.017e-02 (tol = 1.000e-07)
#   Newton iteration 2: r (abs) = 1.207e-06 (tol = 1.000e-08) r (rel) = 1.180e-06 (tol = 1.000e-07)
#   Newton iteration 3: r (abs) = 1.601e-12 (tol = 1.000e-08) r (rel) = 1.566e-12 (tol = 1.000e-07)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# The total power is 354.1 kW
# Maximum theoretical power per turbine (Betz-adjusted): 135.25 kW
# Momentum-sink (raw thrust) power per turbine:          193.21 kW
# Max total power: 0.39 MW
#
# Turbine performance summary:
# -------------------------------------------------------
# Turbine  1: Velocity = 1.95 m/s | Power = 178.71 kW
# Turbine  2: Velocity = 1.94 m/s | Power = 175.34 kW
# -------------------------------------------------------
# Total extracted power: 0.35 MW
# Fraction of park capacity: 91.63%
#
#
# ========  LAYOUT OPTIMISATION SUMMARY  ========
# Initial total power:                    354.53 kW
# Optimised total power:                  354.06 kW
# Maximum theoretical power (no wake):       0.39 MW
# Relative improvement:                    -0.13 %
# Farm efficiency:                         91.63 %
# ===============================================

# %%
try:
    import dolfin_adjoint
    print("✅ dolfin_adjoint is installed.")
except ImportError:
    print("❌ dolfin_adjoint not found.")

try:
    import pyadjoint
    print("✅ pyadjoint is installed.")
except ImportError:
    print("❌ pyadjoint not found.")

import dolfin, dolfin_adjoint
print(dolfin.__file__)
print(dolfin_adjoint.__file__)
# Out:
# /home/zabreedveld/miniconda3/envs/fenicsproject/lib/python3.10/site-packages/ufl/__init__.py:250: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ✅ dolfin_adjoint is installed.
# ✅ pyadjoint is installed.
# /home/zabreedveld/miniconda3/envs/fenicsproject/lib/python3.10/site-packages/dolfin/__init__.py
# /home/zabreedveld/miniconda3/envs/fenicsproject/lib/python3.10/site-packages/dolfin_adjoint/__init__.py
